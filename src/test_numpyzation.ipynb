# %%
from domains import Waveguide
domain = Waveguide()
domain.generate_mesh()
Edges = domain.Edges

# %%
Nedges = len(Edges)

# %%
from numpy_mesh import edge_dtype
import numpy as np

edges = np.zeros(Nedges, dtype=edge_dtype)

# %%
# from labels import EdgeType

# %%
edges = np.array( [ (e.M, e.N, e.l, e.Type ) for e in Edges], dtype=edge_dtype)

# %%
edges[ edges["label"] == EdgeType.SIGMA_R ]
# Out:
# array([([10. ,  0.5], [1., 0.], 1., <EdgeType.SIGMA_R: 4>)],
#       dtype=[('midpoint', '<f8', (2,)), ('normal', '<f8', (2,)), ('length', '<f8'), ('label', 'O')])

# %%
domain.plot_mesh()

# %%
edges["label"].flags
# Out:
#   C_CONTIGUOUS : False
#   F_CONTIGUOUS : False
#   OWNDATA : False
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
